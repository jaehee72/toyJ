# %%
import numpy as np
import pandas as pd

# %%
df0 = pd.read_csv('./generic1.csv', sep = ",", low_memory=False)
df1 = pd.read_csv('./generic2.csv', sep = ",", low_memory=False)
df2 = pd.read_csv('./generic3.csv', sep = ",", low_memory=False)
df3 = pd.read_csv('./generic4.csv', sep = ",", low_memory=False)

# %%
df0
# Out:
#       Unnamed: 0         srcip  sport           dstip  dsport proto state  \
# 0             57  175.45.176.0  29309  149.171.126.14    3000   tcp   FIN
# 1            241  175.45.176.3  55249  149.171.126.10    5060   udp   INT
# 2           1565  175.45.176.2  15985  149.171.126.17      80   tcp   FIN
# 3           2458  175.45.176.2   8037  149.171.126.10      80   tcp   FIN
# 4           2460  175.45.176.2  49950  149.171.126.16    5060   udp   INT
# ...          ...           ...    ...             ...     ...   ...   ...
# 7517      182632  175.45.176.2  59953  149.171.126.10      69   udp   INT
# 7518      182890  175.45.176.3  38535  149.171.126.13      21   tcp   FIN
# 7519      184043  175.45.176.2  47711  149.171.126.18    6504   tcp   FIN
# 7520      184443  175.45.176.2  63132  149.171.126.17      80   tcp   FIN
# 7521      184763  175.45.176.0   8603  149.171.126.18      25   tcp   FIN
#
#            dur  sbytes  dbytes  ...  ct_ftp_cmd  ct_srv_src  ct_srv_dst  \
# ...

# %%
df1
# Out:
#        Unnamed: 0         srcip  sport           dstip  dsport proto state  \
# 0          387276  175.45.176.0      0  149.171.126.12       0  ospf   INT
# 1          387328  175.45.176.1      0  149.171.126.17       0  sctp   INT
# 2          387446  175.45.176.3      0  149.171.126.14       0   gre   INT
# 3          387706  175.45.176.0  55673  149.171.126.12    3000   tcp   FIN
# 4          388765  175.45.176.1  15982  149.171.126.14    5060   udp   INT
# ...           ...           ...    ...             ...     ...   ...   ...
# 27878      699930  175.45.176.3   1043  149.171.126.18      53   udp   INT
# 27879      699931  175.45.176.3   1043  149.171.126.18      53   udp   INT
# 27880      699932  175.45.176.3   1043  149.171.126.18      53   udp   INT
# 27881      699933  175.45.176.3   1043  149.171.126.18      53   udp   INT
# 27882      699934  175.45.176.1  13540  149.171.126.10      80   tcp   FIN
#
# ...

# %%
df2
# Out:
#         Unnamed: 0         srcip  sport           dstip  dsport proto state  \
# 0              264  175.45.176.3  47439  149.171.126.18      53   udp   INT
# 1              266  175.45.176.3  47439  149.171.126.18      53   udp   INT
# 2              267  175.45.176.3  47439  149.171.126.18      53   udp   INT
# 3              268  175.45.176.3  47439  149.171.126.18      53   udp   INT
# 4              269  175.45.176.3  47439  149.171.126.18      53   udp   INT
# ...            ...           ...    ...             ...     ...   ...   ...
# 118193      698602  175.45.176.3  12441  149.171.126.16    6502   tcp   FIN
# 118194      699701  175.45.176.3  56807  149.171.126.10      80   tcp   FIN
# 118195      699905  175.45.176.1  30850  149.171.126.11      80   tcp   FIN
# 118196      699908  175.45.176.1  17386  149.171.126.11    6071   tcp   FIN
# 118197      699961  175.45.176.1  24448  149.171.126.11    5250   tcp   FIN
#
# ...

# %%
df3
# Out:
#        Unnamed: 0         srcip  sport           dstip  dsport proto state  \
# 0              50  175.45.176.1      0  149.171.126.11       0  sctp   INT
# 1             100  175.45.176.0  12334  149.171.126.13    5060   udp   INT
# 2             501  175.45.176.1   1707  149.171.126.10    5060   udp   INT
# 3             595  175.45.176.0  12720  149.171.126.14      80   tcp   FIN
# 4             660  175.45.176.1  14975  149.171.126.11      80   tcp   FIN
# ...           ...           ...    ...             ...     ...   ...   ...
# 61873      440019  175.45.176.0  47439  149.171.126.10      53   udp   INT
# 61874      440020  175.45.176.0  47439  149.171.126.10      53   udp   INT
# 61875      440021  175.45.176.0  47439  149.171.126.10      53   udp   INT
# 61876      440022  175.45.176.0  47439  149.171.126.10      53   udp   INT
# 61877      440023  175.45.176.0  47439  149.171.126.10      53   udp   INT
#
# ...

# %%
df = pd.concat([df0, df1, df2, df3])

# %%
df
# Out:
#        Unnamed: 0         srcip  sport           dstip  dsport proto state  \
# 0              57  175.45.176.0  29309  149.171.126.14    3000   tcp   FIN
# 1             241  175.45.176.3  55249  149.171.126.10    5060   udp   INT
# 2            1565  175.45.176.2  15985  149.171.126.17      80   tcp   FIN
# 3            2458  175.45.176.2   8037  149.171.126.10      80   tcp   FIN
# 4            2460  175.45.176.2  49950  149.171.126.16    5060   udp   INT
# ...           ...           ...    ...             ...     ...   ...   ...
# 61873      440019  175.45.176.0  47439  149.171.126.10      53   udp   INT
# 61874      440020  175.45.176.0  47439  149.171.126.10      53   udp   INT
# 61875      440021  175.45.176.0  47439  149.171.126.10      53   udp   INT
# 61876      440022  175.45.176.0  47439  149.171.126.10      53   udp   INT
# 61877      440023  175.45.176.0  47439  149.171.126.10      53   udp   INT
#
# ...

# %%
df.to_csv('all_generic.csv')
